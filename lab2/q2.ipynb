# %%
import numpy as np
from matplotlib import pyplot as plt

x=np.linspace(1,3,num=300)
y=(np.sin(x)*np.cos(np.pi *x)) / ((x**3 +1)*(x+1))

plt.plot(x,y)

# %%
x=np.arange(2,4,0.15)
y=x**2 / (x-(1/x**2))
plt.plot(x,y)
print(x)
# Out:
# [2.   2.15 2.3  2.45 2.6  2.75 2.9  3.05 3.2  3.35 3.5  3.65 3.8  3.95]
